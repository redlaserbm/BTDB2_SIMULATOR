# %%
from utils import add_project_root
add_project_root()

import b2sim.engine as b2
import b2sim.analysis as dd

# %%
rounds = b2.Rounds(0.1)

farms = [
    b2.initFarm(rounds.getTimeFromRound(7), upgrades = [3,2,0]),
    b2.initFarm(rounds.getTimeFromRound(13.9), upgrades = [3,2,0])
]

initial_state_game = {
    'Cash': 0,
    'Eco': 800,
    'Eco Send': b2.ecoSend(send_name = 'Grouped Yellows'),
    'Rounds': rounds, #Determines the lengths of the rounds in the game state
    'Farms': farms,
    'Game Round': 13.99
}

game_state = b2.GameState(initial_state_game)
game_state.fastForward(target_round = 17)

print("The current cash and eco are (%s,%s)"%(game_state.cash, game_state.eco))
b2.writeLog(game_state.logs, filename = 'base_experiment_log')
dd.viewHistory(game_state)

game_state.eco_cost
# Out:
# [{'Time': 156.85, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]
# The current cash and eco are (4547.999999999998,1217.5999999999922)
#     Time   Type         Message
# 0  285.0  Round  Round 14 start
# 1  297.0  Round  Round 15 start
# 2  313.4  Round  Round 16 start
# 3  346.4  Round  Round 17 start
#             Revenue  Expenses  Profit  Eco Impact  Start Time  End Time
# Farm Index
# 0            2450.0         0  2450.0       238.0       285.0     346.0
# 1            2450.0         0  2450.0       238.0       285.0     346.0
# 40.0

# %%
game_state.logs
# Out:
# ['MESSAGE FROM GameState.__init__(): ',
#  'Initialized Game State!',
#  'The current game round is 13',
#  'The current game time is 284.762 seconds',
#  'The game round start times are given by [0, 6.0, 29.849999999999998, 52.849999999999994, 76.94999999999999, 106.14999999999999, 133.45, 156.85, 180.35, 201.6, 222.29999999999998, 233.85, 248.4, 266.15, 284.95, 297.05, 313.35, 346.40000000000003, 385.65000000000003, 411.8, 448.15000000000003, 456.95000000000005, 473.50000000000006, 503.75000000000006, 516.3000000000001, 576.7500000000001, 614.4000000000001, 643.1500000000001, 668.3000000000001, 692.5500000000001, 739.3000000000001, 749.1, 803.844, 819.8240000000001, 849.0240000000001, 863.9156600000001, 911.5076600000001, 939.6556600000001, 1028.4906600000002, 1093.8614900000002, 1190.3114900000003, 1202.1114900000002, 1244.2414900000003, 1275.6914900000004, 1303.1414900000004, 1324.1414900000004, 1342.4914900000003, 1383.9414900000004, 1405.3914900000004, 1443.9614900000004, 1480.4114900000004, 1491.3114900000005] \n',
#  'MESSAGE FROM GameState.fastForward: ',
#  'Advancing game to time 284.812',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 0, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Warning! Time 0 is too early to call Grouped Yellows. Adjusting the queue time to 156.85',
#  'The eco cost for the send Grouped Yellows is 40.0',
#  'Modified the eco send to Grouped Yellows',
#  'Advancing game to time 284.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 285.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 284.95',
#  'Awarded direct payment 50 at time 284.95',
#  'Recorded cash and eco values (100,800) at time 284.95',
#  'Sent a set of Grouped Yellows at time 284.975',
#  'Currently, the send queue looks like this: ',
#  '[285.21500000000003]',
#  'Recorded cash and eco values (60.0,801.6) at time 285.0',
#  'Advancing game to time 285.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 285.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 285.125',
#  'Currently, the send queue looks like this: ',
#  '[285.21500000000003, 285.45500000000004]',
#  'Recorded cash and eco values (20.0,803.2) at time 285.2',
#  'Advancing game to time 285.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 285.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 285.29',
#  'Awarded direct payment 50 at time 285.29',
#  'Recorded cash and eco values (120.0,803.2) at time 285.29',
#  'Advancing game to time 285.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 285.36875',
#  'Currently, the send queue looks like this: ',
#  '[285.45500000000004, 285.69500000000005]',
#  'Recorded cash and eco values (80.0,804.8) at time 285.4',
#  'Advancing game to time 285.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 285.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 285.51874999999995',
#  'Currently, the send queue looks like this: ',
#  '[285.69500000000005, 285.93500000000006]',
#  'Recorded cash and eco values (40.0,806.4) at time 285.6',
#  'Advancing game to time 285.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 285.64',
#  'Recorded cash and eco values (90.0,806.4) at time 285.64',
#  'Awarded direct payment 50 at time 285.64',
#  'Recorded cash and eco values (140.0,806.4) at time 285.64',
#  'Sent a set of Grouped Yellows at time 285.66874999999993',
#  'Currently, the send queue looks like this: ',
#  '[285.69500000000005, 285.93500000000006, 286.17500000000007]',
#  'Recorded cash and eco values (100.0,808.0) at time 285.7',
#  'Advancing game to time 285.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 285.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 285.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 285.8187499999999',
#  'Currently, the send queue looks like this: ',
#  '[285.93500000000006, 286.17500000000007, 286.4150000000001]',
#  'Recorded cash and eco values (60.0,809.6) at time 285.9',
#  'Advancing game to time 286.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 285.9687499999999',
#  'Currently, the send queue looks like this: ',
#  '[286.17500000000007, 286.4150000000001, 286.6550000000001]',
#  'Awarded direct payment 50 at time 285.98',
#  'Recorded cash and eco values (70.0,811.2) at time 285.98',
#  'Awarded direct payment 50 at time 285.98',
#  'Recorded cash and eco values (120.0,811.2) at time 285.98',
#  'Advancing game to time 286.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 286.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 286.11874999999986',
#  'Currently, the send queue looks like this: ',
#  '[286.17500000000007, 286.4150000000001, 286.6550000000001, 286.8950000000001]',
#  'Recorded cash and eco values (80.0,812.8) at time 286.2',
#  'Advancing game to time 286.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 286.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 286.26874999999984',
#  'Currently, the send queue looks like this: ',
#  '[286.4150000000001, 286.6550000000001, 286.8950000000001, 287.1350000000001]',
#  'Recorded cash and eco values (40.0,814.4) at time 286.3',
#  'Advancing game to time 286.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 286.32',
#  'Recorded cash and eco values (90.0,814.4) at time 286.32',
#  'Awarded direct payment 50 at time 286.32',
#  'Recorded cash and eco values (140.0,814.4) at time 286.32',
#  'Advancing game to time 286.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 286.4187499999998',
#  'Currently, the send queue looks like this: ',
#  '[286.6550000000001, 286.8950000000001, 287.1350000000001, 287.3750000000001]',
#  'Recorded cash and eco values (100.0,816.0) at time 286.5',
#  'Advancing game to time 286.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 286.5687499999998',
#  'Currently, the send queue looks like this: ',
#  '[286.6550000000001, 286.8950000000001, 287.1350000000001, 287.3750000000001, 287.6150000000001]',
#  'Recorded cash and eco values (60.0,817.6) at time 286.6',
#  'Advancing game to time 286.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 286.67',
#  'Recorded cash and eco values (110.0,817.6) at time 286.67',
#  'Awarded direct payment 50 at time 286.67',
#  'Recorded cash and eco values (160.0,817.6) at time 286.67',
#  'Advancing game to time 286.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 286.7187499999998',
#  'Currently, the send queue looks like this: ',
#  '[286.8950000000001, 287.1350000000001, 287.3750000000001, 287.6150000000001, 287.85500000000013]',
#  'Recorded cash and eco values (120.0,819.2) at time 286.75',
#  'Advancing game to time 286.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 286.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 286.86874999999975',
#  'Currently, the send queue looks like this: ',
#  '[286.8950000000001, 287.1350000000001, 287.3750000000001, 287.6150000000001, 287.85500000000013, 288.09500000000014]',
#  'Recorded cash and eco values (80.0,820.8) at time 286.9',
#  'Advancing game to time 287.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 287.01',
#  'Awarded direct payment 50 at time 287.01',
#  'Recorded cash and eco values (180.0,820.8) at time 287.01',
#  'Sent a set of Grouped Yellows at time 287.0187499999997',
#  'Currently, the send queue looks like this: ',
#  '[287.1350000000001, 287.3750000000001, 287.6150000000001, 287.85500000000013, 288.09500000000014, 288.33500000000015]',
#  'Recorded cash and eco values (140.0,822.4) at time 287.1',
#  'Advancing game to time 287.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 287.1687499999997',
#  'Currently, the send queue looks like this: ',
#  '[287.3750000000001, 287.6150000000001, 287.85500000000013, 288.09500000000014, 288.33500000000015, 288.57500000000016]',
#  'Recorded cash and eco values (100.0,824.0) at time 287.2',
#  'Advancing game to time 287.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 287.36',
#  'Awarded direct payment 50 at time 287.36',
#  'Recorded cash and eco values (200.0,824.0) at time 287.36',
#  'Sent a set of Grouped Yellows at time 287.3750000000001',
#  'Currently, the send queue looks like this: ',
#  '[287.6150000000001, 287.85500000000013, 288.09500000000014, 288.33500000000015, 288.57500000000016, 288.81500000000017]',
#  'Recorded cash and eco values (160.0,825.6) at time 287.4',
#  'Advancing game to time 287.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 287.6150000000001',
#  'Currently, the send queue looks like this: ',
#  '[287.85500000000013, 288.09500000000014, 288.33500000000015, 288.57500000000016, 288.81500000000017, 289.0550000000002]',
#  'Awarded direct payment 50 at time 287.7',
#  'Awarded direct payment 50 at time 287.7',
#  'Recorded cash and eco values (220.0,827.2) at time 287.7',
#  'Advancing game to time 287.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 287.85500000000013',
#  'Currently, the send queue looks like this: ',
#  '[288.09500000000014, 288.33500000000015, 288.57500000000016, 288.81500000000017, 289.0550000000002, 289.2950000000002]',
#  'Recorded cash and eco values (180.0,828.8) at time 287.9',
#  'Advancing game to time 288.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded eco payment 828.8 at time 288',
#  'Recorded cash and eco values (1008.8,828.8) at time 288',
#  'Recorded cash and eco values (1008.8,828.8) at time 288.0',
#  'Advancing game to time 288.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 288.04',
#  'Recorded cash and eco values (1058.8,828.8) at time 288.04',
#  'Awarded direct payment 50 at time 288.04',
#  'Recorded cash and eco values (1108.8,828.8) at time 288.04',
#  'Sent a set of Grouped Yellows at time 288.09500000000014',
#  'Currently, the send queue looks like this: ',
#  '[288.33500000000015, 288.57500000000016, 288.81500000000017, 289.0550000000002, 289.2950000000002, 289.5350000000002]',
#  'Recorded cash and eco values (1068.8,830.4) at time 288.1',
#  'Advancing game to time 288.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 288.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 288.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 288.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 288.33500000000015',
#  'Currently, the send queue looks like this: ',
#  '[288.57500000000016, 288.81500000000017, 289.0550000000002, 289.2950000000002, 289.5350000000002, 289.7750000000002]',
#  'Awarded direct payment 50 at time 288.39',
#  'Awarded direct payment 50 at time 288.39',
#  'Recorded cash and eco values (1128.8,832.0) at time 288.39',
#  'Advancing game to time 288.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 288.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 288.57500000000016',
#  'Currently, the send queue looks like this: ',
#  '[288.81500000000017, 289.0550000000002, 289.2950000000002, 289.5350000000002, 289.7750000000002, 290.0150000000002]',
#  'Recorded cash and eco values (1088.8,833.6) at time 288.6',
#  'Advancing game to time 288.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 288.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 288.73',
#  'Awarded direct payment 50 at time 288.73',
#  'Recorded cash and eco values (1188.8,833.6) at time 288.73',
#  'Advancing game to time 288.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 288.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 288.81500000000017',
#  'Currently, the send queue looks like this: ',
#  '[289.0550000000002, 289.2950000000002, 289.5350000000002, 289.7750000000002, 290.0150000000002, 290.2550000000002]',
#  'Recorded cash and eco values (1148.8,835.2) at time 288.9',
#  'Advancing game to time 289.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 289.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 289.0550000000002',
#  'Currently, the send queue looks like this: ',
#  '[289.2950000000002, 289.5350000000002, 289.7750000000002, 290.0150000000002, 290.2550000000002, 290.49500000000023]',
#  'Awarded direct payment 50 at time 289.07',
#  'Awarded direct payment 50 at time 289.07',
#  'Recorded cash and eco values (1208.8,836.8) at time 289.07',
#  'Advancing game to time 289.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 289.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 289.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 289.2950000000002',
#  'Currently, the send queue looks like this: ',
#  '[289.5350000000002, 289.7750000000002, 290.0150000000002, 290.2550000000002, 290.49500000000023, 290.73500000000024]',
#  'Recorded cash and eco values (1168.8,838.4) at time 289.3',
#  'Advancing game to time 289.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 289.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 289.42',
#  'Awarded direct payment 50 at time 289.42',
#  'Recorded cash and eco values (1268.8,838.4) at time 289.42',
#  'Advancing game to time 289.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 289.5350000000002',
#  'Currently, the send queue looks like this: ',
#  '[289.7750000000002, 290.0150000000002, 290.2550000000002, 290.49500000000023, 290.73500000000024, 290.97500000000025]',
#  'Recorded cash and eco values (1228.8,840.0) at time 289.6',
#  'Advancing game to time 289.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 289.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 289.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 289.76',
#  'Awarded direct payment 50 at time 289.76',
#  'Recorded cash and eco values (1328.8,840.0) at time 289.76',
#  'Sent a set of Grouped Yellows at time 289.7750000000002',
#  'Currently, the send queue looks like this: ',
#  '[290.0150000000002, 290.2550000000002, 290.49500000000023, 290.73500000000024, 290.97500000000025, 291.21500000000026]',
#  'Recorded cash and eco values (1288.8,841.6) at time 289.8',
#  'Advancing game to time 289.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 290.0150000000002',
#  'Currently, the send queue looks like this: ',
#  '[290.2550000000002, 290.49500000000023, 290.73500000000024, 290.97500000000025, 291.21500000000026, 291.45500000000027]',
#  'Recorded cash and eco values (1248.8,843.2) at time 290.1',
#  'Advancing game to time 290.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 290.11',
#  'Recorded cash and eco values (1298.8,843.2) at time 290.11',
#  'Awarded direct payment 50 at time 290.11',
#  'Recorded cash and eco values (1348.8,843.2) at time 290.11',
#  'Advancing game to time 290.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 290.2550000000002',
#  'Currently, the send queue looks like this: ',
#  '[290.49500000000023, 290.73500000000024, 290.97500000000025, 291.21500000000026, 291.45500000000027, 291.6950000000003]',
#  'Recorded cash and eco values (1308.8,844.8) at time 290.3',
#  'Advancing game to time 290.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 290.49500000000023',
#  'Currently, the send queue looks like this: ',
#  '[290.73500000000024, 290.97500000000025, 291.21500000000026, 291.45500000000027, 291.6950000000003, 291.9350000000003]',
#  'Recorded cash and eco values (1268.8,846.4) at time 290.5',
#  'Advancing game to time 290.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 290.73500000000024',
#  'Currently, the send queue looks like this: ',
#  '[290.97500000000025, 291.21500000000026, 291.45500000000027, 291.6950000000003, 291.9350000000003, 292.1750000000003]',
#  'Recorded cash and eco values (1228.8,848.0) at time 290.75',
#  'Advancing game to time 290.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 290.97500000000025',
#  'Currently, the send queue looks like this: ',
#  '[291.21500000000026, 291.45500000000027, 291.6950000000003, 291.9350000000003, 292.1750000000003, 292.4150000000003]',
#  'Recorded cash and eco values (1188.8,849.6) at time 291.0',
#  'Advancing game to time 291.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 291.21500000000026',
#  'Currently, the send queue looks like this: ',
#  '[291.45500000000027, 291.6950000000003, 291.9350000000003, 292.1750000000003, 292.4150000000003, 292.6550000000003]',
#  'Recorded cash and eco values (1148.8,851.2) at time 291.25',
#  'Advancing game to time 291.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 291.45500000000027',
#  'Currently, the send queue looks like this: ',
#  '[291.6950000000003, 291.9350000000003, 292.1750000000003, 292.4150000000003, 292.6550000000003, 292.8950000000003]',
#  'Recorded cash and eco values (1108.8,852.8) at time 291.5',
#  'Advancing game to time 291.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 291.6950000000003',
#  'Currently, the send queue looks like this: ',
#  '[291.9350000000003, 292.1750000000003, 292.4150000000003, 292.6550000000003, 292.8950000000003, 293.13500000000033]',
#  'Recorded cash and eco values (1068.8,854.4) at time 291.7',
#  'Advancing game to time 291.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 291.9350000000003',
#  'Currently, the send queue looks like this: ',
#  '[292.1750000000003, 292.4150000000003, 292.6550000000003, 292.8950000000003, 293.13500000000033, 293.37500000000034]',
#  'Recorded cash and eco values (1028.8,856.0) at time 292.0',
#  'Advancing game to time 292.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 292.1750000000003',
#  'Currently, the send queue looks like this: ',
#  '[292.4150000000003, 292.6550000000003, 292.8950000000003, 293.13500000000033, 293.37500000000034, 293.61500000000035]',
#  'Recorded cash and eco values (988.8,857.6) at time 292.2',
#  'Advancing game to time 292.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 292.4150000000003',
#  'Currently, the send queue looks like this: ',
#  '[292.6550000000003, 292.8950000000003, 293.13500000000033, 293.37500000000034, 293.61500000000035, 293.85500000000036]',
#  'Recorded cash and eco values (948.8,859.2) at time 292.5',
#  'Advancing game to time 292.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 292.6550000000003',
#  'Currently, the send queue looks like this: ',
#  '[292.8950000000003, 293.13500000000033, 293.37500000000034, 293.61500000000035, 293.85500000000036, 294.09500000000037]',
#  'Recorded cash and eco values (908.8,860.8) at time 292.7',
#  'Advancing game to time 292.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 292.8950000000003',
#  'Currently, the send queue looks like this: ',
#  '[293.13500000000033, 293.37500000000034, 293.61500000000035, 293.85500000000036, 294.09500000000037, 294.3350000000004]',
#  'Recorded cash and eco values (868.8,862.4) at time 292.9',
#  'Advancing game to time 293.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 293.13500000000033',
#  'Currently, the send queue looks like this: ',
#  '[293.37500000000034, 293.61500000000035, 293.85500000000036, 294.09500000000037, 294.3350000000004, 294.5750000000004]',
#  'Recorded cash and eco values (828.8,864.0) at time 293.2',
#  'Advancing game to time 293.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 293.37500000000034',
#  'Currently, the send queue looks like this: ',
#  '[293.61500000000035, 293.85500000000036, 294.09500000000037, 294.3350000000004, 294.5750000000004, 294.8150000000004]',
#  'Recorded cash and eco values (788.8,865.6) at time 293.4',
#  'Advancing game to time 293.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 293.61500000000035',
#  'Currently, the send queue looks like this: ',
#  '[293.85500000000036, 294.09500000000037, 294.3350000000004, 294.5750000000004, 294.8150000000004, 295.0550000000004]',
#  'Recorded cash and eco values (748.8,867.2) at time 293.7',
#  'Advancing game to time 293.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 293.85500000000036',
#  'Currently, the send queue looks like this: ',
#  '[294.09500000000037, 294.3350000000004, 294.5750000000004, 294.8150000000004, 295.0550000000004, 295.2950000000004]',
#  'Recorded cash and eco values (708.8,868.8) at time 293.9',
#  'Advancing game to time 294.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded eco payment 868.8 at time 294',
#  'Recorded cash and eco values (1577.6,868.8) at time 294',
#  'Recorded cash and eco values (1577.6,868.8) at time 294.0',
#  'Advancing game to time 294.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 294.09500000000037',
#  'Currently, the send queue looks like this: ',
#  '[294.3350000000004, 294.5750000000004, 294.8150000000004, 295.0550000000004, 295.2950000000004, 295.5350000000004]',
#  'Recorded cash and eco values (1537.6,870.4) at time 294.1',
#  'Advancing game to time 294.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 294.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 294.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 294.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 294.3350000000004',
#  'Currently, the send queue looks like this: ',
#  '[294.5750000000004, 294.8150000000004, 295.0550000000004, 295.2950000000004, 295.5350000000004, 295.77500000000043]',
#  'Recorded cash and eco values (1497.6,872.0) at time 294.4',
#  'Advancing game to time 294.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 294.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 294.5750000000004',
#  'Currently, the send queue looks like this: ',
#  '[294.8150000000004, 295.0550000000004, 295.2950000000004, 295.5350000000004, 295.77500000000043, 296.01500000000044]',
#  'Recorded cash and eco values (1457.6,873.6) at time 294.6',
#  'Advancing game to time 294.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 294.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 294.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 294.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 294.8150000000004',
#  'Currently, the send queue looks like this: ',
#  '[295.0550000000004, 295.2950000000004, 295.5350000000004, 295.77500000000043, 296.01500000000044, 296.25500000000045]',
#  'Recorded cash and eco values (1417.6,875.2) at time 294.9',
#  'Advancing game to time 295.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 295.0550000000004',
#  'Currently, the send queue looks like this: ',
#  '[295.2950000000004, 295.5350000000004, 295.77500000000043, 296.01500000000044, 296.25500000000045, 296.49500000000046]',
#  'Recorded cash and eco values (1377.6,876.8) at time 295.1',
#  'Advancing game to time 295.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 295.2950000000004',
#  'Currently, the send queue looks like this: ',
#  '[295.5350000000004, 295.77500000000043, 296.01500000000044, 296.25500000000045, 296.49500000000046, 296.73500000000047]',
#  'Recorded cash and eco values (1337.6,878.4) at time 295.3',
#  'Advancing game to time 295.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 295.5350000000004',
#  'Currently, the send queue looks like this: ',
#  '[295.77500000000043, 296.01500000000044, 296.25500000000045, 296.49500000000046, 296.73500000000047, 296.9750000000005]',
#  'Recorded cash and eco values (1297.6,880.0) at time 295.6',
#  'Advancing game to time 295.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 295.77500000000043',
#  'Currently, the send queue looks like this: ',
#  '[296.01500000000044, 296.25500000000045, 296.49500000000046, 296.73500000000047, 296.9750000000005, 297.2150000000005]',
#  'Recorded cash and eco values (1257.6,881.6) at time 295.8',
#  'Advancing game to time 295.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 296.01500000000044',
#  'Currently, the send queue looks like this: ',
#  '[296.25500000000045, 296.49500000000046, 296.73500000000047, 296.9750000000005, 297.2150000000005, 297.4550000000005]',
#  'Recorded cash and eco values (1217.6,883.2) at time 296.1',
#  'Advancing game to time 296.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 296.25500000000045',
#  'Currently, the send queue looks like this: ',
#  '[296.49500000000046, 296.73500000000047, 296.9750000000005, 297.2150000000005, 297.4550000000005, 297.6950000000005]',
#  'Recorded cash and eco values (1177.6,884.8) at time 296.3',
#  'Advancing game to time 296.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 296.49500000000046',
#  'Currently, the send queue looks like this: ',
#  '[296.73500000000047, 296.9750000000005, 297.2150000000005, 297.4550000000005, 297.6950000000005, 297.9350000000005]',
#  'Recorded cash and eco values (1137.6,886.4) at time 296.5',
#  'Advancing game to time 296.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 296.73500000000047',
#  'Currently, the send queue looks like this: ',
#  '[296.9750000000005, 297.2150000000005, 297.4550000000005, 297.6950000000005, 297.9350000000005, 298.1750000000005]',
#  'Recorded cash and eco values (1097.6,888.0) at time 296.75',
#  'Advancing game to time 296.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 296.9750000000005',
#  'Currently, the send queue looks like this: ',
#  '[297.2150000000005, 297.4550000000005, 297.6950000000005, 297.9350000000005, 298.1750000000005, 298.41500000000053]',
#  'Recorded cash and eco values (1057.6,889.6) at time 297.0',
#  'Advancing game to time 297.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 297.05',
#  'Recorded cash and eco values (1107.6,889.6) at time 297.05',
#  'Awarded direct payment 50 at time 297.05',
#  'Recorded cash and eco values (1157.6,889.6) at time 297.05',
#  'Advancing game to time 297.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 297.2150000000005',
#  'Currently, the send queue looks like this: ',
#  '[297.4550000000005, 297.6950000000005, 297.9350000000005, 298.1750000000005, 298.41500000000053, 298.65500000000054]',
#  'Recorded cash and eco values (1117.6,891.2) at time 297.25',
#  'Advancing game to time 297.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 297.4550000000005',
#  'Currently, the send queue looks like this: ',
#  '[297.6950000000005, 297.9350000000005, 298.1750000000005, 298.41500000000053, 298.65500000000054, 298.89500000000055]',
#  'Recorded cash and eco values (1077.6,892.8) at time 297.5',
#  'Advancing game to time 297.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 297.61',
#  'Awarded direct payment 50 at time 297.61',
#  'Recorded cash and eco values (1177.6,892.8) at time 297.61',
#  'Sent a set of Grouped Yellows at time 297.6950000000005',
#  'Currently, the send queue looks like this: ',
#  '[297.9350000000005, 298.1750000000005, 298.41500000000053, 298.65500000000054, 298.89500000000055, 299.13500000000056]',
#  'Recorded cash and eco values (1137.6,894.4) at time 297.7',
#  'Advancing game to time 297.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 297.9350000000005',
#  'Currently, the send queue looks like this: ',
#  '[298.1750000000005, 298.41500000000053, 298.65500000000054, 298.89500000000055, 299.13500000000056, 299.37500000000057]',
#  'Recorded cash and eco values (1097.6,896.0) at time 298.0',
#  'Advancing game to time 298.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 298.18',
#  'Awarded direct payment 50 at time 298.18',
#  'Recorded cash and eco values (1197.6,896.0) at time 298.18',
#  'Sent a set of Grouped Yellows at time 298.1750000000005',
#  'Currently, the send queue looks like this: ',
#  '[298.41500000000053, 298.65500000000054, 298.89500000000055, 299.13500000000056, 299.37500000000057, 299.6150000000006]',
#  'Recorded cash and eco values (1157.6,897.6) at time 298.2',
#  'Advancing game to time 298.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 298.41500000000053',
#  'Currently, the send queue looks like this: ',
#  '[298.65500000000054, 298.89500000000055, 299.13500000000056, 299.37500000000057, 299.6150000000006, 299.8550000000006]',
#  'Recorded cash and eco values (1117.6,899.2) at time 298.5',
#  'Advancing game to time 298.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 298.65500000000054',
#  'Currently, the send queue looks like this: ',
#  '[298.89500000000055, 299.13500000000056, 299.37500000000057, 299.6150000000006, 299.8550000000006, 300.0950000000006]',
#  'Recorded cash and eco values (1077.6,900.8) at time 298.7',
#  'Advancing game to time 298.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 298.74',
#  'Recorded cash and eco values (1127.6,900.8) at time 298.74',
#  'Awarded direct payment 50 at time 298.74',
#  'Recorded cash and eco values (1177.6,900.8) at time 298.74',
#  'Advancing game to time 298.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 298.89500000000055',
#  'Currently, the send queue looks like this: ',
#  '[299.13500000000056, 299.37500000000057, 299.6150000000006, 299.8550000000006, 300.0950000000006, 300.3350000000006]',
#  'Recorded cash and eco values (1137.6,902.4) at time 298.9',
#  'Advancing game to time 299.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 299.13500000000056',
#  'Currently, the send queue looks like this: ',
#  '[299.37500000000057, 299.6150000000006, 299.8550000000006, 300.0950000000006, 300.3350000000006, 300.5750000000006]',
#  'Recorded cash and eco values (1097.6,904.0) at time 299.2',
#  'Advancing game to time 299.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 299.3',
#  'Awarded direct payment 50 at time 299.3',
#  'Recorded cash and eco values (1197.6,904.0) at time 299.3',
#  'Advancing game to time 299.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 299.37500000000057',
#  'Currently, the send queue looks like this: ',
#  '[299.6150000000006, 299.8550000000006, 300.0950000000006, 300.3350000000006, 300.5750000000006, 300.8150000000006]',
#  'Recorded cash and eco values (1157.6,905.6) at time 299.4',
#  'Advancing game to time 299.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 299.6150000000006',
#  'Currently, the send queue looks like this: ',
#  '[299.8550000000006, 300.0950000000006, 300.3350000000006, 300.5750000000006, 300.8150000000006, 301.05500000000063]',
#  'Recorded cash and eco values (1117.6,907.2) at time 299.7',
#  'Advancing game to time 299.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 299.8550000000006',
#  'Currently, the send queue looks like this: ',
#  '[300.0950000000006, 300.3350000000006, 300.5750000000006, 300.8150000000006, 301.05500000000063, 301.29500000000064]',
#  'Awarded direct payment 50 at time 299.86',
#  'Awarded direct payment 50 at time 299.86',
#  'Recorded cash and eco values (1177.6,908.8) at time 299.86',
#  'Advancing game to time 300.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded eco payment 908.8 at time 300',
#  'Recorded cash and eco values (2086.4,908.8) at time 300.0',
#  'Advancing game to time 300.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 300.0950000000006',
#  'Currently, the send queue looks like this: ',
#  '[300.3350000000006, 300.5750000000006, 300.8150000000006, 301.05500000000063, 301.29500000000064, 301.53500000000065]',
#  'Recorded cash and eco values (2046.4,910.4) at time 300.1',
#  'Advancing game to time 300.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 300.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 300.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 300.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 300.3350000000006',
#  'Currently, the send queue looks like this: ',
#  '[300.5750000000006, 300.8150000000006, 301.05500000000063, 301.29500000000064, 301.53500000000065, 301.77500000000066]',
#  'Recorded cash and eco values (2006.4,912.0) at time 300.4',
#  'Advancing game to time 300.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 300.43',
#  'Recorded cash and eco values (2056.4,912.0) at time 300.43',
#  'Awarded direct payment 50 at time 300.43',
#  'Recorded cash and eco values (2106.4,912.0) at time 300.43',
#  'Advancing game to time 300.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 300.5750000000006',
#  'Currently, the send queue looks like this: ',
#  '[300.8150000000006, 301.05500000000063, 301.29500000000064, 301.53500000000065, 301.77500000000066, 302.01500000000067]',
#  'Recorded cash and eco values (2066.4,913.6) at time 300.6',
#  'Advancing game to time 300.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 300.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 300.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 300.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 300.8150000000006',
#  'Currently, the send queue looks like this: ',
#  '[301.05500000000063, 301.29500000000064, 301.53500000000065, 301.77500000000066, 302.01500000000067, 302.2550000000007]',
#  'Recorded cash and eco values (2026.4,915.2) at time 300.9',
#  'Advancing game to time 301.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded direct payment 50 at time 300.99',
#  'Recorded cash and eco values (2076.4,915.2) at time 300.99',
#  'Awarded direct payment 50 at time 300.99',
#  'Recorded cash and eco values (2126.4,915.2) at time 300.99',
#  'Advancing game to time 301.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 301.05500000000063',
#  'Currently, the send queue looks like this: ',
#  '[301.29500000000064, 301.53500000000065, 301.77500000000066, 302.01500000000067, 302.2550000000007, 302.4950000000007]',
#  'Recorded cash and eco values (2086.4,916.8) at time 301.1',
#  'Advancing game to time 301.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 301.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 301.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 301.29500000000064',
#  'Currently, the send queue looks like this: ',
#  '[301.53500000000065, 301.77500000000066, 302.01500000000067, 302.2550000000007, 302.4950000000007, 302.7350000000007]',
#  'Recorded cash and eco values (2046.4,918.4) at time 301.3',
#  'Advancing game to time 301.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 301.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 301.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 301.53500000000065',
#  'Currently, the send queue looks like this: ',
#  '[301.77500000000066, 302.01500000000067, 302.2550000000007, 302.4950000000007, 302.7350000000007, 302.9750000000007]',
#  'Awarded direct payment 50 at time 301.55',
#  ...]

# %%
game_state.rounds.round_starts[17]
# Out:
# 346.40000000000003
