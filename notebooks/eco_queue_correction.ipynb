# %%
from utils import add_project_root
add_project_root()

import b2sim.engine as b2
import b2sim.analysis as dd

# %%
rounds = b2.Rounds(0.1)

eco_queue = [
    b2.ecoSend(send_name='Grouped Yellows', time = rounds.getTimeFromRound(15))
]

initial_state_game = {
    'Cash': 0,
    'Eco': 1000,
    'Eco Queue': eco_queue,
    'Rounds': rounds, #Determines the lengths of the rounds in the game state
    'Game Round': 13.99
}

game_state = b2.GameState(initial_state_game)
game_state.fastForward(target_round = 16)

print("The current cash and eco are (%s,%s)"%(game_state.cash, game_state.eco))
b2.writeLog(game_state.logs, filename = 'eco_queue_correction_test_log')
dd.viewHistory(game_state)
# Out:
# The current cash and eco are (2286.3999999999933,1116.799999999995)
#     Time   Type                        Message
# 0  284.8    Eco             Change eco to Zero
# 1  285.0  Round                 Round 14 start
# 2  297.0  Round                 Round 15 start
# 3  297.0    Eco  Change eco to Grouped Yellows
# 4  313.4  Round                 Round 16 start

# %%
game_state.logs
# Out:
# ['MESSAGE FROM GameState.__init__(): ',
#  'Initialized Game State!',
#  'The current game round is 13',
#  'The current game time is 284.762 seconds',
#  'The game round start times are given by [0, 6.0, 29.849999999999998, 52.849999999999994, 76.94999999999999, 106.14999999999999, 133.45, 156.85, 180.35, 201.6, 222.29999999999998, 233.85, 248.4, 266.15, 284.95, 297.05, 313.35, 346.40000000000003, 385.65000000000003, 411.8, 448.15000000000003, 456.95000000000005, 473.50000000000006, 503.75000000000006, 516.3000000000001, 576.7500000000001, 614.4000000000001, 643.1500000000001, 668.3000000000001, 692.5500000000001, 739.3000000000001, 749.1, 803.844, 819.8240000000001, 849.0240000000001, 863.9156600000001, 911.5076600000001, 939.6556600000001, 1028.4906600000002, 1093.8614900000002, 1190.3114900000003, 1202.1114900000002, 1244.2414900000003, 1275.6914900000004, 1303.1414900000004, 1324.1414900000004, 1342.4914900000003, 1383.9414900000004, 1405.3914900000004, 1443.9614900000004, 1480.4114900000004, 1491.3114900000005] \n',
#  'MESSAGE FROM GameState.fastForward: ',
#  'Advancing game to time 284.812',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'The eco cost for the send Zero is 0.0',
#  'Modified the eco send to Zero',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 284.9',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 285.0',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 285.1',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 285.2',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 285.25',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 285.3',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 285.4',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 285.5',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 285.6',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 285.7',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 285.75',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 285.8',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 285.9',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 286.0',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 286.1',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 286.2',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 286.25',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 286.3',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 286.4',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 286.5',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 286.6',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 286.7',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 286.75',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 286.8',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 286.9',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 287.0',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 287.1',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 287.2',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 287.25',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 287.3',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 287.4',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 287.5',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 287.6',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 287.7',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 287.75',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 287.8',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 287.9',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 288.0',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Awarded eco payment 1000 at time 288',
#  'Recorded cash and eco values (1000,1000) at time 288.0',
#  'Advancing game to time 288.1',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 288.2',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 288.25',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 288.3',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 288.4',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 288.5',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 288.6',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 288.7',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 288.75',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 288.8',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 288.9',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 289.0',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 289.1',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 289.2',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 289.25',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 289.3',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 289.4',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 289.5',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 289.6',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 289.7',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 289.75',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 289.8',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 289.9',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 290.0',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 290.1',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 290.2',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 290.25',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 290.3',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 290.4',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 290.5',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 290.6',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 290.7',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 290.75',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 290.8',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 290.9',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 291.0',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 291.1',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 291.2',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 291.25',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 291.3',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 291.4',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 291.5',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 291.6',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 291.7',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
# ...
#  'Advancing game to time 295.4',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 295.5',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 295.6',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 295.7',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 295.75',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 295.8',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 295.9',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 296.0',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 296.1',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 296.2',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 296.25',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 296.3',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 296.4',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 296.5',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 296.6',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 296.7',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 296.75',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 296.8',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 296.9',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 297.0',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Advancing game to time 297.1',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'self.changeNow returned False!',
#  'ecoQueueCorrection returned: ',
#  "[{'Time': 297.05, 'Send Name': 'Grouped Yellows', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'The eco cost for the send Grouped Yellows is 40.0',
#  'Modified the eco send to Grouped Yellows',
#  'Advancing game to time 297.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 297.05',
#  'Currently, the send queue looks like this: ',
#  '[297.29]',
#  'Recorded cash and eco values (1960.0,1001.6) at time 297.1',
#  'Advancing game to time 297.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 297.2',
#  'Currently, the send queue looks like this: ',
#  '[297.29, 297.53000000000003]',
#  'Recorded cash and eco values (1920.0,1003.2) at time 297.2',
#  'Advancing game to time 297.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 297.34999999999997',
#  'Currently, the send queue looks like this: ',
#  '[297.53000000000003, 297.77000000000004]',
#  'Recorded cash and eco values (1880.0,1004.8) at time 297.4',
#  'Advancing game to time 297.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 297.49999999999994',
#  'Currently, the send queue looks like this: ',
#  '[297.53000000000003, 297.77000000000004, 298.01000000000005]',
#  'Recorded cash and eco values (1840.0,1006.4) at time 297.5',
#  'Advancing game to time 297.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 297.6499999999999',
#  'Currently, the send queue looks like this: ',
#  '[297.77000000000004, 298.01000000000005, 298.25000000000006]',
#  'Recorded cash and eco values (1800.0,1008.0) at time 297.7',
#  'Advancing game to time 297.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 297.7999999999999',
#  'Currently, the send queue looks like this: ',
#  '[298.01000000000005, 298.25000000000006, 298.49000000000007]',
#  'Recorded cash and eco values (1760.0,1009.6) at time 297.8',
#  'Advancing game to time 297.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 297.9499999999999',
#  'Currently, the send queue looks like this: ',
#  '[298.01000000000005, 298.25000000000006, 298.49000000000007, 298.7300000000001]',
#  'Recorded cash and eco values (1720.0,1011.2) at time 298.0',
#  'Advancing game to time 298.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 298.09999999999985',
#  'Currently, the send queue looks like this: ',
#  '[298.25000000000006, 298.49000000000007, 298.7300000000001, 298.9700000000001]',
#  'Recorded cash and eco values (1680.0,1012.8) at time 298.1',
#  'Advancing game to time 298.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 298.24999999999983',
#  'Currently, the send queue looks like this: ',
#  '[298.25000000000006, 298.49000000000007, 298.7300000000001, 298.9700000000001, 299.2100000000001]',
#  'Recorded cash and eco values (1640.0,1014.4) at time 298.25',
#  'Advancing game to time 298.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 298.3999999999998',
#  'Currently, the send queue looks like this: ',
#  '[298.49000000000007, 298.7300000000001, 298.9700000000001, 299.2100000000001, 299.4500000000001]',
#  'Recorded cash and eco values (1600.0,1016.0) at time 298.4',
#  'Advancing game to time 298.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Sent a set of Grouped Yellows at time 298.5499999999998',
#  ...]

# %%
rounds = b2.Rounds(0.1)

eco_queue = [
    b2.ecoSend(send_name='Grouped Reds', time = rounds.getTimeFromRound(14)),
    b2.ecoSend(send_name='Grouped Blues', time = rounds.getTimeFromRound(15)),
]

initial_state_game = {
    'Cash': 0,
    'Eco': 1000,
    'Eco Queue': eco_queue,
    'Rounds': rounds, #Determines the lengths of the rounds in the game state
    'Game Round': 13.99
}

game_state = b2.GameState(initial_state_game)
game_state.fastForward(target_round = 16)

print("The current cash and eco are (%s,%s)"%(game_state.cash, game_state.eco))
b2.writeLog(game_state.logs, filename = 'eco_queue_correction_test_log')
dd.viewHistory(game_state)
# Out:
# The current cash and eco are (5000,1000)
#     Time   Type             Message
# 0  284.8    Eco  Change eco to Zero
# 1  285.0  Round      Round 14 start
# 2  297.0  Round      Round 15 start
# 3  313.4  Round      Round 16 start

# %%
game_state.logs
# Out:
# ['MESSAGE FROM GameState.__init__(): ',
#  'Initialized Game State!',
#  'The current game round is 13',
#  'The current game time is 284.762 seconds',
#  'The game round start times are given by [0, 6.0, 29.849999999999998, 52.849999999999994, 76.94999999999999, 106.14999999999999, 133.45, 156.85, 180.35, 201.6, 222.29999999999998, 233.85, 248.4, 266.15, 284.95, 297.05, 313.35, 346.40000000000003, 385.65000000000003, 411.8, 448.15000000000003, 456.95000000000005, 473.50000000000006, 503.75000000000006, 516.3000000000001, 576.7500000000001, 614.4000000000001, 643.1500000000001, 668.3000000000001, 692.5500000000001, 739.3000000000001, 749.1, 803.844, 819.8240000000001, 849.0240000000001, 863.9156600000001, 911.5076600000001, 939.6556600000001, 1028.4906600000002, 1093.8614900000002, 1190.3114900000003, 1202.1114900000002, 1244.2414900000003, 1275.6914900000004, 1303.1414900000004, 1324.1414900000004, 1342.4914900000003, 1383.9414900000004, 1405.3914900000004, 1443.9614900000004, 1480.4114900000004, 1491.3114900000005] \n',
#  'MESSAGE FROM GameState.fastForward: ',
#  'Advancing game to time 284.812',
#  'ecoQueueCorrection called with eco queue: ',
#  "[{'Time': 284.95, 'Send Name': 'Grouped Reds', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}, {'Time': 297.05, 'Send Name': 'Grouped Blues', 'Max Send Amount': None, 'Fortified': False, 'Camoflauge': False, 'Regrow': False, 'Max Eco Amount': None, 'Max Send Time': None, 'Queue Threshold': 6}]",
#  'Warning! Time 284.95 is too late to call Grouped Reds. Removing from eco queue',
#  'Warning! Time 297.05 is too late to call Grouped Blues. Removing from eco queue',
#  'self.changeNow returned False! The queue is empty!',
#  'The eco cost for the send Zero is 0.0',
#  'Modified the eco send to Zero',
#  'ecoQueueCorrection returned: ',
#  '[]',
#  'Advancing game to time 284.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 285.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 285.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 285.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 285.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 285.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 285.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 285.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 285.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 285.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 285.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 285.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 285.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 286.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 286.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 286.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 286.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 286.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 286.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 286.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 286.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 286.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 286.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 286.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 286.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 287.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 288.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded eco payment 1000 at time 288',
#  'Recorded cash and eco values (1000,1000) at time 288.0',
#  'Advancing game to time 288.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 288.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 288.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 288.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 288.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 288.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 288.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 288.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 288.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 288.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 288.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 289.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 289.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 289.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 289.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 289.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 289.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 289.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 289.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 289.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 289.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 289.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 289.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 290.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 291.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 292.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 293.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 294.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded eco payment 1000 at time 294',
#  'Recorded cash and eco values (2000,1000) at time 294.0',
#  'Advancing game to time 294.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 294.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 294.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 294.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 294.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 294.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 294.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 294.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 294.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 294.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 294.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 295.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 296.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 297.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 298.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 299.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 300.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded eco payment 1000 at time 300',
#  'Recorded cash and eco values (3000,1000) at time 300.0',
#  'Advancing game to time 300.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 300.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 300.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 300.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 300.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 300.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 300.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 300.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 300.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 300.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 300.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 301.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 301.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 301.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 301.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 301.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 301.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 301.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 301.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 301.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 301.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 301.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 301.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 302.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 302.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 302.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 302.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 302.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 302.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 302.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 302.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 302.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 302.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 302.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 302.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 303.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 303.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 303.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 303.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 303.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 303.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 303.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 303.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 303.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 303.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 303.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 303.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 304.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 304.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 304.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 304.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 304.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 304.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 304.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 304.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 304.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 304.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 304.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 304.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 305.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 305.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 305.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 305.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 305.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 305.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 305.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 305.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 305.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 305.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 305.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 305.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 306.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded eco payment 1000 at time 306',
#  'Recorded cash and eco values (4000,1000) at time 306.0',
#  'Advancing game to time 306.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 306.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 306.25',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 306.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 306.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 306.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 306.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 306.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 306.75',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 306.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 306.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 307.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 307.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 307.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 307.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 307.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 307.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 307.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 307.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 307.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 307.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 308.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 308.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 308.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 308.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 308.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 308.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 308.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 308.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 308.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 308.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 309.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 309.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 309.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 309.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 309.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 309.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 309.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 309.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 309.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 309.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 310.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 310.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 310.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 310.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 310.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 310.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 310.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 310.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 310.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 310.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 311.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 311.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 311.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 311.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 311.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 311.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 311.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 311.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 311.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 311.9',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 312.0',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Awarded eco payment 1000 at time 312',
#  'Recorded cash and eco values (5000,1000) at time 312.0',
#  'Advancing game to time 312.1',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 312.2',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 312.3',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 312.4',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 312.5',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 312.6',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 312.7',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 312.8',
#  'ecoQueueCorrection called with eco queue: ',
#  '[]',
#  'Advancing game to time 312.9',
#  'ecoQueueCorrection called with eco queue: ',
#  ...]

# %%
rounds = b2.Rounds(0.1)

eco_queue = [
    b2.ecoSend(send_name='Grouped Yellows', time = rounds.getTimeFromRound(13.9)),
    b2.ecoSend(send_name='Grouped Pinks', time = rounds.getTimeFromRound(14.5)),
]

initial_state_game = {
    'Cash': 0,
    'Eco': 1000,
    'Eco Queue': eco_queue,
    'Rounds': rounds, #Determines the lengths of the rounds in the game state
    'Game Round': 13.99
}

game_state = b2.GameState(initial_state_game)
game_state.fastForward(target_round = 16)

print("The current cash and eco are (%s,%s)"%(game_state.cash, game_state.eco))
b2.writeLog(game_state.logs, filename = 'eco_queue_correction_test_log')
dd.viewHistory(game_state)
# Out:
# The current cash and eco are (655.7999999999943,1182.899999999997)
#     Time   Type                        Message
# 0  284.8    Eco  Change eco to Grouped Yellows
# 1  285.0  Round                 Round 14 start
# 2  291.0    Eco    Change eco to Grouped Pinks
# 3  297.0  Round                 Round 15 start
# 4  313.4  Round                 Round 16 start
